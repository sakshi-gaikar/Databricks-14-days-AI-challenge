# %% [markdown]
# # Day 1 – Platform Setup & First Steps in PySpark
#
# This notebook documents my first hands-on experience with Databricks and PySpark.
# The goal was to understand how Spark DataFrames work and how basic operations differ from Pandas.

# %%
# Sample student data
data = [
    (1, "Aarav", "Data Science", 88),
    (2, "Meera", "AI & ML", 92),
    (3, "Rohit", "Data Science", 65),
    (4, "Ananya", "AI & ML", 78),
    (5, "Kunal", "Data Analytics", 85)
]

# Column names for the DataFrame
columns= ["student_id", "student_name", "course", "score"]

# Creating Spark DataFrame
df = spark.createDataFrame( data,columns)

# %%
## Viewing the DataFrame
df.show()
# Out:
# +----------+------------+--------------+-----+
# |student_id|student_name|        course|score|
# +----------+------------+--------------+-----+
# |         1|       Aarav|  Data Science|   88|
# |         2|       Meera|       AI & ML|   92|
# |         3|       Rohit|  Data Science|   65|
# |         4|      Ananya|       AI & ML|   78|
# |         5|       Kunal|Data Analytics|   85|
# +----------+------------+--------------+-----+

# %%
# Top-performing students
df.filter(df.score > 80).show()
# Out:
# +----------+------------+--------------+-----+
# |student_id|student_name|        course|score|
# +----------+------------+--------------+-----+
# |         1|       Aarav|  Data Science|   88|
# |         2|       Meera|       AI & ML|   92|
# |         5|       Kunal|Data Analytics|   85|
# +----------+------------+--------------+-----+
